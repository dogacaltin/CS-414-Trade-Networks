# %%
import pandas as pd
import numpy as np

# %%
df_trades = pd.read_csv("Dyadic_COW_4.0.csv", encoding="latin1")

# %%
df_trades.head()
# Out:
#    ccode1  ccode2  year                 importer1 importer2      flow1  \
# 0       2      20  1920  United States of America    Canada  611.85999
# 1       2      20  1921  United States of America    Canada  335.44000
# 2       2      20  1922  United States of America    Canada  364.01999
# 3       2      20  1923  United States of America    Canada  416.00000
# 4       2      20  1924  United States of America    Canada  399.14001
#
#        flow2  smoothflow1  smoothflow2  smoothtotrade  ...  dip2  trdspike  \
# 0  735.47998    611.85999    735.47998     1347.34000  ...     0         0
# 1  442.98999    335.44000    442.98999      778.42999  ...     0         0
# 2  502.84000    364.01999    502.84000      866.85999  ...     0         0
# 3  598.14001    416.00000    598.14001     1014.14000  ...     0         0
# 4  496.32001    399.14001    496.32001      895.46002  ...     0         0
#
#    tradedip  bel_lux_alt_flow1  bel_lux_alt_flow2  china_alt_flow1  \
# ...

# %%
len(df_trades[(df_trades["flow1"] == 0) | (df_trades["flow2"] == 0)])
# Out:
# 299527

# %%
countries1 = df_trades["importer1"].unique()
dicti = {}
for state in countries1:
    countries2 = df_trades[df_trades["importer1"]==state]["importer2"].unique()
    dicti[state] = len(countries2)
dicti = dict(sorted(dicti.items(), key=lambda item: item[1], reverse=True))
for i in dicti:
    print(i, dicti[i])
# Out:
# United States of America 206
# Haiti 202
# Canada 200
# Cuba 200
# Bahamas 198
# Dominican Republic 198
# Jamaica 195
# Trinidad and Tobago 194
# Barbados 192
# Mexico 191
# Dominica 190
# Grenada 190
# Guatemala 189
# St. Lucia 188
# St. Vincent and the Grenadines 187
# Antigua & Barbuda 186
# St. Kitts and Nevis 185
# Honduras 185
# El Salvador 184
# Belize 183
# Nicaragua 183
# Colombia 183
# Venezuela 182
# Costa Rica 180
# Panama 179
# Ecuador 179
# Peru 178
# Brazil 177
# Bolivia 176
# Guyana 175
# Paraguay 175
# Suriname 174
# Chile 174
# Argentina 173
# United Kingdom 171
# Uruguay 169
# Netherlands 169
# Belgium 168
# France 166
# Ireland 165
# Switzerland 163
# Luxembourg 162
# Spain 162
# Portugal 160
# Liechtenstein 157
# Germany 156
# Monaco 153
# Poland 152
# Austria 150
# Andorra 149
# Hungary 149
# Italy 146
# Czech Republic 143
# Malta 143
# Slovakia 142
# Albania 142
# San Marino 140
# Yugoslavia 139
# Montenegro 137
# Macedonia 136
# Czechoslovakia 135
# ...

# %%
countries4 = df_trades["importer2"].unique()
dicti2 = {}
for state in countries4:
    countries3 = df_trades[df_trades["importer2"]==state]["importer1"].unique()
    dicti2[state] = len(countries3)

dicti2 = dict(sorted(dicti2.items(), key=lambda item: item[1], reverse=True))
for i in dicti2:
    print(i, dicti2[i])
# Out:
# Samoa 199
# Fiji 194
# Federated States of Micronesia 194
# Marshall Islands 192
# Palau 192
# New Zealand 190
# Solomon Islands 190
# Nauru 190
# Vanuatu 189
# Tonga 189
# Australia 188
# Papua New Guinea 188
# Tuvalu 187
# Indonesia 186
# Kiribati 186
# Philippines 185
# Malaysia 182
# Singapore 182
# Brunei 182
# Vietnam 180
# East Timor 180
# Thailand 179
# Laos 179
# Cambodia 178
# Nepal 176
# Sri Lanka 174
# Maldives 174
# Japan 173
# Myanmar 173
# Pakistan 171
# Bangladesh 171
# India 169
# Bhutan 169
# China 167
# South Korea 167
# North Korea 166
# Taiwan 165
# Mongolia 164
# Afghanistan 157
# Kazakhstan 157
# Uzbekistan 156
# Oman 155
# Kyrgyzstan 155
# United Arab Emirates 154
# Tajikistan 154
# Qatar 153
# Turkmenistan 153
# Kuwait 152
# Bahrain 152
# Yemen 149
# Saudi Arabia 148
# Egypt 147
# Israel 147
# Jordan 146
# Turkey 145
# Lebanon 145
# Iran 144
# Syria 144
# Iraq 142
# Republic of Vietnam 142
# Tunisia 140
# Morocco 138
# Sudan 138
# Libya 137
# Algeria 135
# ...

# %%
for x in

# %%
national_trade = pd.read_csv("National_COW_4.0.csv", encoding="latin1")

# %%
len(df_trades)
# Out:
# 886828
